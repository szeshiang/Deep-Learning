# %% [markdown]
# <a href="https://colab.research.google.com/github/szeshiang/Deep-Learning/blob/main/3_Mar_24_Image_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load the data
from skimage import io
import matplotlib.pyplot as plt

# %%
image=io.imread('leopard.jpg')
io.imshow(image)

# %%
i,(im1,im2,im3,im4)=plt.subplots(1,4,sharey=True)
i.set_figwidth(20)

im1.imshow(image)
im2.imshow(image[:,:,0]) # show only Red channel pixels; not to confuse channel plane with colour itself
im3.imshow(image[:,:,1]) # Green
im4.imshow(image[:,:,2]) # Blue
i.suptitle('Original and RGB image channels')
# Out:
# Text(0.5, 0.98, 'Original and RGB image channels')
