# %% [markdown]
# <a href="https://colab.research.google.com/github/szeshiang/Deep-Learning/blob/main/9_Mar_24_Image_Processing_with_Data_Augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load the data
from skimage import io
import matplotlib.pyplot as plt

# %%
image=io.imread('leopard.jpg')
io.imshow(image)

# %%
i,(im1,im2,im3,im4)=plt.subplots(1,4,sharey=True)
i.set_figwidth(20)

im1.imshow(image)
im2.imshow(image[:,:,0]) # show only Red channel pixels; not to confuse channel plane with colour itself
im3.imshow(image[:,:,1]) # Green
im4.imshow(image[:,:,2]) # Blue
i.suptitle('Original and RGB image channels')
# Out:
# Text(0.5, 0.98, 'Original and RGB image channels')

# %% [markdown]
# **Data Augmentation**
# using Image Data Generator
#
# (functions like a separate entity)

# %%
import tensorflow
import keras
from skimage import io
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator

# %%
samples = expand_dims(image,0)
datagen = ImageDataGenerator(horizontal_flip=True, vertical_flip=True)
it = datagen.flow(samples, batch_size=1)
fig, im = plt.subplots(nrows=1, ncols=3, figsize=(15,15))

for i in range(3):

    modified_image = next(it)[0].astype('uint8')

    im[i].imshow(modified_image)

# %%
datagen = ImageDataGenerator(brightness_range=[0.5,2.0])
it = datagen.flow(samples, batch_size=1)
fig, im = plt.subplots(nrows=1, ncols=3, figsize=(15,15))

for i in range(3):

    modified_image = next(it)[0].astype('uint8')

    im[i].imshow(modified_image)
